# %% [markdown]
# <a href="https://colab.research.google.com/github/iqbalkp/TUGAS-SLO/blob/main/Tugas_1_SLO.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# NAMA : IQBAL KURNIAWAN PERDANA

# %% [markdown]
# NIM : 201012320002

# %%
import pandas as pd
from google.colab import files
import io

# %%
uploaded = files.upload()
# Out:
#      <input type="file" id="files-dc85a28d-cd19-4869-8c6c-0a11af33b409" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-dc85a28d-cd19-4869-8c6c-0a11af33b409">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
for fn in uploaded.keys():
  print('User uploaded file "{name}" with length {length} bytes'.format(name=fn, length=len(uploaded[fn])))
# Out:
# User uploaded file "epl-goalScorer(20-21).csv" with length 75342 bytes

# %%
df = pd.read_csv(io.StringIO(uploaded['epl-goalScorer(20-21).csv'].decode('utf-8')))

# %%
k=df.head()
k
# Out:
#    Unnamed: 0    id      player_name  games  time  goals         xG  assists  \
# 0           0   647       Harry Kane     35  3097     23  22.174859       14
# 1           1  1250    Mohamed Salah     37  3085     22  20.250847        5
# 2           2  1228  Bruno Fernandes     37  3117     18  16.019454       12
# 3           3   453    Son Heung-Min     37  3139     17  11.023287       10
# 4           4   822  Patrick Bamford     38  3085     17  18.401863        7
#
#           xA  shots  key_passes  yellow_cards  red_cards position  \
# 0   7.577094    138          49             1          0        F
# 1   6.528526    126          55             0          0    F M S
# 2  11.474996    121          95             6          0      M S
# 3   9.512992     68          75             0          0    F M S
# 4   3.782247    107          30             3          0      F S
#
#           team_title  npg       npxG    xGChain  xGBuildup
# ...

# %%
df.head(3)
# Out:
#    Unnamed: 0    id      player_name  games  time  goals         xG  assists  \
# 0           0   647       Harry Kane     35  3097     23  22.174859       14
# 1           1  1250    Mohamed Salah     37  3085     22  20.250847        5
# 2           2  1228  Bruno Fernandes     37  3117     18  16.019454       12
#
#           xA  shots  key_passes  yellow_cards  red_cards position  \
# 0   7.577094    138          49             1          0        F
# 1   6.528526    126          55             0          0    F M S
# 2  11.474996    121          95             6          0      M S
#
#           team_title  npg       npxG    xGChain  xGBuildup
# 0          Tottenham   19  19.130183  24.995648   4.451257
# 1          Liverpool   16  15.683834  28.968234   9.800236
# 2  Manchester United    9   8.407840  26.911412  11.932285

# %%
df_sorted = df.sort_values('goals', ascending=False)
df_top10 = df_sorted.head(10)
print(df_top10[['player_name', 'goals']])
# Out:
#              player_name  goals
# 0             Harry Kane     23
# 1          Mohamed Salah     22
# 2        Bruno Fernandes     18
# 3          Son Heung-Min     17
# 4        Patrick Bamford     17
# 5  Dominic Calvert-Lewin     16
# 6            Jamie Vardy     15
# 7          Ollie Watkins     14
# 8         Ilkay Gündogan     13
# 9    Alexandre Lacazette     13

# %%
df_sorted = df.sort_values('time', ascending=False)
df_top10 = df_sorted.head(10)
print(df_top10[['player_name', 'time']])
# Out:
#                player_name  time
# 296            Hugo Lloris  3420
# 378      Emiliano Martinez  3420
# 311      Kasper Schmeichel  3420
# 110  Pierre-Emile Højbjerg  3420
# 40           Stuart Dallas  3412
# 327           Matt Targett  3407
# 480            Luke Ayling  3400
# 204       Andrew Robertson  3391
# 55         Youri Tielemans  3359
# 7            Ollie Watkins  3330

# %%
df_sorted = df.sort_values('assists', ascending=False)
df_top10 = df_sorted.head(10)
print(df_top10[['player_name', 'assists']])
# Out:
#          player_name  assists
# 0         Harry Kane       14
# 2    Bruno Fernandes       12
# 58   Kevin De Bruyne       11
# 3      Son Heung-Min       10
# 51     Jack Grealish       10
# 15   Marcus Rashford        9
# 6        Jamie Vardy        9
# 57          Raphinha        9
# 49       Timo Werner        8
# 281  Aaron Cresswell        8

# %%
df_Manchester = df[df['team_title'] == 'Manchester United']
df_Manchester_sorted = df_Manchester.sort_values('goals', ascending=False)
df_top4_Manchester = df_Manchester_sorted.nlargest(4, 'goals')
#print(df_top4_Manchester)
df_top4_Manchester = df_top4_Manchester.nlargest(4, 'goals')
print(df_top4_Manchester[['player_name','team_title', 'goals']])
# Out:
#         player_name         team_title  goals
# 2   Bruno Fernandes  Manchester United     18
# 15  Marcus Rashford  Manchester United     11
# 23   Edinson Cavani  Manchester United     10
# 47  Mason Greenwood  Manchester United      7

# %%
df_goals_per_team = df.groupby('team_title')['goals'].sum()
df_goals_per_team_sorted = df_goals_per_team.sort_values(ascending=False)
tim_dengan_goal_terbanyak = df_goals_per_team_sorted.index[0]
print(tim_dengan_goal_terbanyak)
# Out:
# Manchester City

# %%
df_assists = df.groupby('player_name')['assists'].sum()
df_assists_sorted = df_assists.sort_values(ascending=False)
top_assister = df_assists_sorted.index[0]
df_top_assist = df[df['player_name'] == top_assister]
total_cards = df_top_assist['red_cards'].sum() + df_top_assist['yellow_cards'].sum()
print(total_cards)
# Out:
# 1

# %%
df['total_assists'] = df.groupby('player_name')['assists'].transform('sum')
df['total_goals'] = df.groupby('player_name')['goals'].transform('sum')
df_sorted = df.sort_values(by=['total_assists', 'total_goals'], ascending=False)
df_result = df_sorted[['player_name', 'total_assists', 'total_goals', 'team_title']].head(1)
print(df_result.to_string())
# Out:
#   player_name  total_assists  total_goals team_title
# 0  Harry Kane             14           23  Tottenham

# %%
df_team_goals = df.groupby('team_title')['goals'].sum()
df_team_goals_sorted = df_team_goals.sort_values(ascending=False)
df_result = df_team_goals_sorted.head(5)
print(df_result.to_string())
# Out:
# team_title
# Manchester City      77
# Manchester United    68
# Tottenham            66
# Liverpool            64
# Leicester            64

# %%
df['total_cards'] = df['red_cards'] + df['yellow_cards']
df_min_cards = df.loc[df['total_cards'] == df['total_cards'].min()]
df_min_cards_sorted = df_min_cards.sort_values(by='goals', ascending=False)
df_result = df_min_cards_sorted[['player_name', 'total_cards', 'total_goals', 'team_title']]
print(df_result.to_string())
# Out:
#                  player_name  total_cards  total_goals               team_title
# 1              Mohamed Salah            0           22                Liverpool
# 3              Son Heung-Min            0           17                Tottenham
# 13                Chris Wood            0           12                  Burnley
# 28              Riyad Mahrez            0            9          Manchester City
# 29             Harvey Barnes            0            9                Leicester
# 33              Jarrod Bowen            0            8                 West Ham
# 37                Phil Foden            0            8          Manchester City
# 50             Danny Welbeck            0            6                 Brighton
# 52             Tammy Abraham            0            6                  Chelsea
# 60           Callum Robinson            0            5     West Bromwich Albion
# 72              Raúl Jiménez            0            4  Wolverhampton Wanderers
# ...
